# %% [markdown]
# ### Dates

# %%
from datetime import datetime, date, timedelta

# %%
my_date = date(2026,3,24)

# %%
my_date
# Out:
# datetime.date(2026, 3, 24)

# %%
type(my_date)
# Out:
# datetime.date

# %%
today = date.today()
today
# Out:
# datetime.date(2026, 3, 24)

# %%
now = da

# %% [markdown]
# ### Dates with pandas
